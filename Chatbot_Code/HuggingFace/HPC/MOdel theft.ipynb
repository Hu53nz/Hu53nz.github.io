# %%
#Step 1: Query the Chatbot
import json  
from langchain_community.chat_models import ChatOllama  
from langchain_core.prompts import ChatPromptTemplate  
  
# Initialize the model and prompt  
template = """Question: {question} Answer: Let's think step by step."""  
prompt = ChatPromptTemplate.from_template(template)  
model = ChatOllama(model="llama3.1")  
chain = prompt | model  
  
# Function to query the chatbot  
def query_chatbot(queries):  
    responses = []  
    for query in queries:  
        response = chain.invoke({"question": query})  
        response_text = response.content  # Adjust this line based on the actual attribute name  
        responses.append({"query": query, "response": response_text})  
    return responses  
  
# Example queries  
queries = [  
    "What is AI?",  
    "Tell me a joke.",  
    "How does photosynthesis work?",  
    "Explain the theory of relativity.",  
    "What are the benefits of exercise?",  
    "How does the internet work?",  
    "What is machine learning?",  
    "Tell me about quantum computing.",  
    "What are black holes?",  
    "Describe the water cycle.",  
    "How do vaccines work?",  
    "What is blockchain technology?",  
    "Explain the greenhouse effect.",  
    "What is the difference between weather and climate?",  
    "How does a computer virus spread?",  
    "What are the main functions of the human brain?",  
    "What is the significance of the Turing test?",  
    "How do plants grow?",  
    "What is the purpose of a resume?",  
    "Explain Newton's laws of motion.",  
    "What are the stages of cellular respiration?",  
    "Tell me about the Great Wall of China.",  
    "How do economies work?",  
    "What is the role of DNA in genetics?",  
    "What are the different types of renewable energy?",  
    "What is the significance of the Fibonacci sequence?",  
    "Explain the concept of supply and demand.",  
    "What is the function of the liver?",  
    "How do electric cars work?",  
    "What is the history of the internet?",  
    "Describe the structure of an atom.",  
    "How do we measure time?",  
    "What are the effects of climate change?",  
    "What is the importance of biodiversity?",  
    "Explain the principle of relativity in simple terms.",  
    "What are the causes of deforestation?",  
    "What is social media?",  
    "How does gravity work?",  
    "What are the health benefits of meditation?",  
    "What is the human genome project?",  
    "How do smartphones work?",  
    "What are the effects of pollution?",  
    "What is the difference between a hypothesis and a theory?",  
    "How does the electoral system work?",  
    "What is an ecosystem?",  
    "How do cryptocurrencies work?",  
    "What is artificial intelligence?",  
    "Explain the process of evolution.",  
    "What is a neural network?",  
    "What are the main types of clouds?",  
    "How does a camera work?",  
    "What are the principles of design?",  
    "What is the significance of the Scientific Method?",  
    "How does a magnet work?",  
    "What are the layers of the Earth?",  
    "What is the process of photosynthesis?",  
    "How does the stock market work?",  
    "What are the benefits of reading?",  
    "How does sound travel?",  
    "What is the role of mitochondria?",  
    "What is the history of vaccines?",  
    "What are the causes of earthquakes?",  
    "How does a solar panel work?",  
    "What is the importance of financial literacy?",  
    "Explain the concept of time zones.",  
    "What is the significance of the Magna Carta?",  
    "How do wind turbines generate electricity?",  
    "What are the main causes of global warming?",  
    "How does a combustion engine work?",  
    "What is the importance of critical thinking?",  
    "How do you write a business plan?",  
    "What are the key components of a healthy diet?",  
    "What is the process of DNA replication?",  
    "What are the main types of financial markets?",  
    "How do you conduct a scientific experiment?",  
    "What is the purpose of the United Nations?",  
    "Explain the concept of peer pressure.",  
    "What is the role of the kidneys?",  
    "How does a hydraulic system work?",  
    "What are the components of a computer system?",  
    "What is the significance of the civil rights movement?",  
    "What is a feedback loop in ecology?",  
    "How do you create a website?",  
    "What are the effects of overfishing?",  
    "How does the brain process information?",  
    "What is the function of the circulatory system?",  
    "What are the basic principles of economics?",  
    "How do solar eclipses occur?",  
    "What is the significance of cultural diversity?",  
    "What are the causes of poverty?",  
    "How does a refrigerator work?",  
    "What is the role of enzymes in the body?",  
    "What are the different types of art?",  
    "What is the importance of community service?",  
    "How does an optical fiber work?",  
    "What are the impacts of social inequality?",  
    "What is the significance of the Bill of Rights?",  
    "How do you build a successful team?",  
    "What is the process of natural selection?",  
    "What are the main features of a democracy?",  
    "How do we define happiness?",  
    "What is the role of advertising in society?",  
    "What are the characteristics of living organisms?",  
    "How do you manage stress effectively?",  
    "What is the process of carbon cycling?",  
    "What is the significance of the moon landing?",  
    "How do you write an effective essay?",  
    "What are the advantages of teamwork?",  
    "How does the human eye work?",  
    "What is the importance of education?",  
    "What is the role of technology in modern life?",  
    "How do you create a marketing strategy?",  
    "What are the basic principles of physics?",  
    "What is the significance of the theory of evolution?",  
    "How do you develop a business idea?",  
    "What are the causes of climate change?",  
    "How does a vaccine work?",  
    "What is the importance of ethics in business?",  
    "What are the characteristics of a healthy relationship?",  
    "How do you stay motivated?",  
    "What is the impact of globalization?",  
    "What is the significance of the Olympic Games?",  
    "How do you solve a math problem?",  
    "What are the effects of technology on communication?",  
    "How does climate affect biodiversity?",  
    "What is the importance of mental health?",  
    "How do you conduct market research?",  
    "What are the challenges of urbanization?",  
    "What is the significance of the Renaissance?",  
    "How do you prepare for a job interview?",  
    "What are the benefits of volunteering?",  
    "What is the role of government in society?",  
    "How does music affect our emotions?",  
    "What is the importance of conservation?",  
    "How do you manage your time effectively?",  
    "What are the impacts of artificial intelligence?",  
    "What is the role of the media in society?",  
    "How do you handle conflict?",  
    "What is the significance of diversity in the workplace?",  
    "How does cultural heritage shape identity?",  
    "What are the causes of addiction?",  
    "How do you practice self-care?",  
    "What is the importance of sports in society?",  
    "How does a computer network work?",  
    "What are the characteristics of a good leader?",  
    "How do you set goals effectively?",  
    "What is the role of non-profits in society?",  
    "How does the body maintain homeostasis?",  
    "What are the challenges of sustainable development?",  
    "What is the importance of personal finance?",  
    "How do you effectively communicate ideas?",  
    "What are the characteristics of effective teams?",  
    "How does language influence thought?",  
    "What is the role of art in society?",  
    "How do you create a successful project?",  
    "What are the impacts of climate on agriculture?",  
    "How does social media influence behavior?",  
    "What is the significance of historical events?",  
    "How do you conduct a needs assessment?",  
    "What are the causes of species extinction?",  
    "How does exercise affect mental health?",  
    "What is the role of parents in education?",  
    "How do you create an effective resume?",  
    "What are the impacts of poverty on health?",  
    "How does technology change the job market?",  
    "What is the significance of scientific discoveries?",  
    "How do you build effective relationships?",  
    "What are the advantages of learning a second language?",  
    "How does culture influence behavior?",  
    "What is the importance of self-reflection?",  
    "How do you develop critical thinking skills?",  
    "What are the effects of media on society?",  
    "How does peer pressure affect decisions?",  
    "What is the role of government in public health?",  
    "How do you manage change in an organization?",  
    "What are the characteristics of successful entrepreneurs?",  
    "How does nature affect mental well-being?",  
    "What is the significance of human rights?",  
    "How do you create a positive work environment?",  
    "What are the causes of unemployment?",  
    "How does art reflect culture?",  
    "What is the importance of lifelong learning?",  
    "How do you set priorities effectively?",  
    "What are the impacts of technological advancement?",  
    "How does culture shape values?",  
    "What is the significance of environmental sustainability?",  
    "How do you foster creativity?",  
    "What are the characteristics of effective communication?",  
    "How does public speaking influence leadership?",  
    "What is the role of technology in education?",  
    "How do you conduct effective meetings?",  
    "What are the effects of work-life balance?",  
    "How does community engagement benefit society?",  
    "What is the significance of youth empowerment?",  
    "How do you practice active listening?",  
    "What are the challenges of remote work?",  
    "How does nutrition impact health?",  
    "What is the importance of cultural awareness?",  
    "How do you develop resilience?",  
    "What are the effects of discrimination?",  
    "How does creativity influence innovation?",  
    "What is the significance of teamwork?",  
    "How do you manage your emotions effectively?",  
    "What are the benefits of cultural exchange?",  
    "How does technology impact privacy?",  
    "What is the role of philanthropy in society?",  
    "How do you stay organized?",  
    "What are the characteristics of successful leaders?",  
    "How does motivation influence performance?",  
    "What is the significance of historical context?",  
    "How do you build a strong network?",  
    "What are the impacts of economic inequality?",  
    "How does childhood development affect adulthood?",  
    "What is the importance of social justice?",  
    "How do you create an inclusive environment?",  
    "What are the benefits of mindfulness?",  
    "How does communication shape relationships?",  
    "What is the significance of cultural traditions?",  
    "How do you handle failure?",  
    "What are the causes of mental health issues?",  
    "How does collaboration enhance productivity?",  
    "What is the importance of empathy?",  
    "How do you create effective goals?",  
    "What are the characteristics of effective leaders?",  
    "How does conflict resolution improve relationships?",  
    "What is the significance of art in education?",  
    "How do you practice gratitude?",  
    "What are the impacts of social networks?",  
    "How does research influence policy?",  
    "What is the importance of personal branding?",  
    "How do you develop a strong work ethic?",  
    "What are the effects of globalization on culture?",  
    "How does self-awareness affect personal growth?",  
    "What is the significance of teamwork in sports?",  
    "How do you build trust in relationships?",  
    "What are the characteristics of a healthy work culture?",  
    "How does volunteering benefit communities?",  
    "What is the importance of critical analysis?",  
    "How do you develop emotional intelligence?",  
    "What are the impacts of childhood experiences on adulthood?",  
    "How does public speaking enhance communication skills?",  
    "What is the significance of global citizenship?",  
    "How do you cultivate a growth mindset?",  
    "What are the effects of advertising on behavior?",  
    "How does cultural identity influence decisions?",  
    "What is the importance of ethical decision-making?",  
    "How do you manage expectations effectively?",  
    "What are the impacts of technology on education?",  
    "How does effective communication improve teamwork?",  
    "What is the significance of diversity in education?",  
    "How do you build resilience in children?",  
    "What are the effects of environmental degradation?",  
    "How does physical health impact mental health?",  
    "What is the importance of strategic planning?",  
    "How do you create a successful marketing campaign?",  
    "What are the impacts of stress on health?",  
    "How does positive reinforcement influence behavior?",  
    "What is the significance of mentorship?",  
    "How do you encourage innovation in teams?",  
    "What are the characteristics of an effective mentor?",  
    "How does financial literacy impact personal success?",  
    "What is the importance of work-life harmony?",  
    "How do you create a vision statement?",  
    "What are the effects of cultural shock?",  
    "How does collaboration foster creativity?",  
    "What is the significance of historical preservation?",  
    "How do you navigate workplace politics?",  
    "What are the benefits of cultural competency?",  
    "How does self-discipline influence success?",  
    "What is the importance of teamwork in project management?",  
    "How do you effectively manage a team?",  
    "What are the characteristics of a successful project?",  
  
    # Add more diverse queries  
]  
  
# Record chatbot responses  
responses = query_chatbot(queries)  
  
# Save responses to a file  
with open("chatbot_responses.json", "w") as f:  
    json.dump(responses, f)

# %%
import sys
print(sys.executable)
# Out:
# /home/FYP/husen001/.conda/envs/new_env/bin/python

# %%
#Step 2: Train a Surrogate Model
import json  
from sklearn.feature_extraction.text import CountVectorizer  
from sklearn.linear_model import LogisticRegression  
  
# Load the recorded responses  
with open("chatbot_responses.json", "r") as f:  
    data = json.load(f)  
  
# Prepare the data for training  
X = [item["query"] for item in data]  
y = [item["response"] for item in data]  
  
# Vectorize the input queries  
vectorizer = CountVectorizer()  
X_vectorized = vectorizer.fit_transform(X)  
  
# Train a simple surrogate model  
model = LogisticRegression()  
model.fit(X_vectorized, y)  
  
# Save the surrogate model and vectorizer  
import pickle  
with open("surrogate_model.pkl", "wb") as f:  
    pickle.dump(model, f)  
with open("vectorizer.pkl", "wb") as f:  
    pickle.dump(vectorizer, f)

# %%
import pickle
import json

import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from langchain_community.chat_models import ChatOllama
from langchain_core.prompts import ChatPromptTemplate

# Load the surrogate model and vectorizer
with open("surrogate_model.pkl", "rb") as f:
    surrogate_model = pickle.load(f)
with open("vectorizer.pkl", "rb") as f:
    vectorizer = pickle.load(f)

# Initialize the original chatbot model and prompt
template = """Question: {question} Answer: Let's think step by step."""
prompt = ChatPromptTemplate.from_template(template)
model = ChatOllama(model="llama3.1")
chain = prompt | model

# Function to get responses from the surrogate model
def get_surrogate_response(query):
    # Ensure we use the same vectorizer that the surrogate model was trained with
    query_vectorized = vectorizer.transform([query])
    response = surrogate_model.predict(query_vectorized)
    return response[0]

# Example evaluation
test_queries = [
    # Personal Development and Success
    "How can you improve your time management skills?",
    "What are effective strategies for achieving goals?",
    "How does mindfulness contribute to personal success?",
    "Why is self-reflection important in personal growth?",
    "How can you overcome procrastination?",
    "What role does resilience play in achieving success?",
    "How can journaling help in self-improvement?",
    "What is the impact of setting SMART goals?",
    "Why is lifelong learning important for personal growth?",
    "How do you develop a growth mindset?",

    # Teamwork and Leadership
    "How do you resolve conflicts within a team?",
    "What are the qualities of a good leader?",
    "How do you build trust among team members?",
    "What are the key principles of servant leadership?",
    "How does diversity improve teamwork?",
    "What are effective techniques for motivating a team?",
    "How do you handle criticism as a team leader?",
    "What are the characteristics of high-performing teams?",
    "How can team-building activities improve productivity?",
    "What is the role of empathy in leadership?",

    # Education and Learning
    "How does technology enhance education?",
    "What are effective study techniques for students?",
    "Why is critical thinking important in education?",
    "How can teachers promote creativity in the classroom?",
    "What is the impact of online learning on education?",
    "How can students improve their focus while studying?",
    "What are the benefits of collaborative learning?",
    "How does education influence career opportunities?",
    "What are strategies to overcome learning challenges?",
    "How can gamification improve learning outcomes?",

    # Health and Wellness
    "What are the benefits of regular exercise?",
    "How does stress affect physical health?",
    "What are effective ways to improve mental health?",
    "How does sleep impact overall well-being?",
    "What are the advantages of maintaining a balanced diet?",
    "How can you cultivate a positive mindset?",
    "What are strategies to manage anxiety?",
    "Why is hydration important for health?",
    "How do hobbies contribute to mental well-being?",
    "What is the importance of social connections for health?",

    # Technology and Innovation
    "How does AI impact the future of work?",
    "What are the ethical implications of AI?",
    "How can blockchain revolutionize industries?",
    "What are the advantages of 5G technology?",
    "How does automation affect job opportunities?",
    "What are the challenges of implementing IoT?",
    "How does cybersecurity protect digital assets?",
    "What is the role of big data in decision-making?",
    "How can renewable energy technologies be improved?",
    "What are the implications of quantum computing?",

    # Society and Culture
    "How does culture influence communication?",
    "What are the benefits of cultural diversity?",
    "How does media shape public opinion?",
    "What are the effects of globalization on society?",
    "How can we preserve endangered languages?",
    "Why is cultural heritage important?",
    "How does social media affect mental health?",
    "What is the role of art in society?",
    "How does language influence thought?",
    "What are strategies to reduce cultural bias?",

    # Environment and Sustainability
    "What are effective ways to combat climate change?",
    "How can individuals reduce their carbon footprint?",
    "What is the impact of deforestation on biodiversity?",
    "How can cities become more sustainable?",
    "What are the benefits of renewable energy?",
    "How does plastic pollution affect marine life?",
    "What are the advantages of green buildings?",
    "How does recycling contribute to environmental health?",
    "What is the role of technology in conservation?",
    "How can businesses promote sustainability?",

    # Philosophy and Ethics
    "What is the importance of ethics in decision-making?",
    "How does philosophy shape human understanding?",
    "What are the key principles of utilitarianism?",
    "How do moral values influence behavior?",
    "What is the role of free will in human actions?",
    "How does existentialism explore human purpose?",
    "What are the ethical challenges of scientific research?",
    "How do cultural norms affect ethical perceptions?",
    "What is the relationship between justice and fairness?",
    "How does ethics influence leadership?",

    # History and Politics
    "What are the causes of major historical revolutions?",
    "How did World War II shape the modern world?",
    "What is the significance of ancient civilizations?",
    "How do political ideologies influence governance?",
    "What is the impact of colonization on modern societies?",
    "How does democracy promote individual freedom?",
    "What are the lessons learned from the Cold War?",
    "How has globalization changed political dynamics?",
    "What is the role of international organizations in peacekeeping?",
    "How does history influence cultural identity?",

    # Miscellaneous
    "What are the benefits of volunteering?",
    "How does humor impact human relationships?",
    "What is the role of curiosity in innovation?",
    "How do traditions shape societal values?",
    "What are strategies for effective public speaking?",
    "How does gratitude enhance personal happiness?",
    "What is the significance of non-verbal communication?",
    "How do hobbies contribute to personal growth?",
    "What are the benefits of reading fiction?",
    "How does music influence emotions?",  
]

# Store responses and compute similarity scores
original_responses = []
surrogate_responses = []
similarity_scores = []

for query in test_queries:
    original_response = chain.invoke({"question": query})
    original_response_text = original_response.content  # Adjust based on actual attribute name
    surrogate_response_text = get_surrogate_response(query)
    
    # Calculate cosine similarity
    # Use the same vectorizer to transform both responses
    response_vectorizer = TfidfVectorizer().fit([original_response_text, surrogate_response_text])
    vectors = response_vectorizer.transform([original_response_text, surrogate_response_text])
    similarity = cosine_similarity(vectors[0], vectors[1])[0, 0]
    
    # Append data for visualization
    original_responses.append(original_response_text)
    surrogate_responses.append(surrogate_response_text)
    similarity_scores.append(similarity)

    print(f"Query: {query}")
    print(f"Original Response: {original_response_text}")
    print(f"Surrogate Response: {surrogate_response_text}")
    print(f"Similarity Score: {similarity:.2f}")
    print()


# Create a list to store the results
results = []

for query, original_response_text, surrogate_response_text, similarity in zip(
        test_queries, original_responses, surrogate_responses, similarity_scores):
    # Structure the result as a dictionary
    results.append({
        "query": query,
        "original_response": original_response_text,
        "surrogate_response": surrogate_response_text,
        "similarity_score": similarity
    })

# Write the results to a JSON file
with open("responses_comparison.json", "w", encoding="utf-8") as json_file:
    json.dump(results, json_file, ensure_ascii=False, indent=4)

print("Responses have been stored in responses_comparison.json")

# Plot the similarity scores
# Out:
# /tmp/ipykernel_1517034/3709792974.py:19: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import ChatOllama``.
#   model = ChatOllama(model="llama3.1")
# Query: How can you improve your time management skills?
# Original Response: Improving time management skills requires a strategic approach. Here are some steps to help you achieve better time management:
#
# 1. **Set Clear Goals**: Establishing specific, measurable, achievable, relevant, and time-bound (SMART) goals helps you focus on what's important. Break down large objectives into smaller tasks to maintain momentum.
#
# 2. **Track Your Time**: For one week or two, write down how you spend every hour of your day. This activity will help you understand where your time is going, allowing you to identify areas for improvement. It also helps in pinpointing time-wasting activities and distractions.
#
# 3. **Make a To-Do List**: Write down everything that needs to be done. Prioritize tasks based on their urgency and importance using the Eisenhower Matrix:
#    - Urgent & Important (Do First)
#    - Not Urgent but Important (Schedule)
#    - Urgent but Not Important (Delegate)
#    - Not Urgent & Not Important (Eliminate)
#
# 4. **Use a Calendar or Planner**: Plan out your day, week, and month using a physical calendar or planner. This visual tool helps in scheduling tasks and appointments more effectively.
#
# 5. **Learn to Say No**: Be mindful of commitments that can drain your time without contributing to your goals. Saying "no" politely but firmly protects your schedule from non-essential activities.
#
# 6. **Avoid Multitasking**: While it might seem efficient, multitasking often leads to divided attention and decreased productivity. Focus on one task at a time to ensure you're giving your best effort.
#
# 7. **Take Breaks**: Regular breaks help in maintaining energy levels and preventing burnout. Use the Pomodoro Technique: Work for 25 minutes, then take a 5-minute break before returning to work.
#
# 8. **Review and Adjust**: Periodically review how well you're managing your time. Identify areas that need improvement and adjust your strategies accordingly.
#
# 9. **Use Technology Wisely**: Utilize tools like calendars, reminders, and apps designed for productivity and organization. However, be aware of potential distractions these tools can cause if not used wisely.
#
# 10. **Practice Mindfulness and Self-Compassion**: Cultivate a mindset that allows you to adapt to changing situations and forgive yourself when mistakes occur. This approach helps in maintaining a positive relationship with time management.
#
# Implementing these strategies requires patience, self-reflection, and practice. Remember, improving time management is a journey rather than a destination, and it's essential to be flexible and adjust your methods as needed.
# Surrogate Response: Navigating workplace politics requires diplomacy, tact, and communication skills.
# Similarity Score: 0.10
#
# Query: What are effective strategies for achieving goals?
# Original Response: Achieving goals requires a thoughtful and structured approach. Here are some effective strategies to consider:
#
# 1. **Set SMART Goals**: Make sure your goals are Specific, Measurable, Achievable, Relevant, and Time-bound. This will help you stay focused and motivated.
# 2. **Break Down Big Goals into Smaller Ones**: Divide large goals into smaller, manageable tasks. This will make the goal seem less overwhelming and more achievable.
# 3. **Create a Plan of Action**: Develop a step-by-step plan to achieve your goal. Identify potential obstacles and develop contingency plans to overcome them.
# 4. **Set Deadlines and Milestones**: Establish specific deadlines and milestones to track progress and stay on track.
# 5. **Prioritize Tasks**: Identify the most important tasks that need to be completed to achieve your goal, and prioritize them accordingly.
# 6. **Track Progress**: Regularly monitor your progress toward your goal. Celebrate successes and identify areas for improvement.
# 7. **Stay Focused and Motivated**: Surround yourself with positive influences, stay committed to your goals, and remind yourself why achieving the goal is important to you.
# 8. **Be Adaptable**: Life is unpredictable, and circumstances may change. Be prepared to adjust your plan if necessary, but remain committed to your overall goal.
#
# Additionally, consider these advanced strategies:
#
# 1. **Use the Power of Visualization**: Imagine yourself successfully achieving your goal. Visualizing success can boost motivation and confidence.
# 2. **Leverage Accountability**: Share your goals with a trusted friend or mentor and ask them to hold you accountable. This can provide an added motivation to stay on track.
# 3. **Practice Self-Care**: Taking care of your physical, emotional, and mental well-being is essential for maintaining energy and focus throughout the goal-achieving process.
#
# By incorporating these effective strategies into your approach, you'll be well on your way to achieving your goals!
# Surrogate Response: Cultural competency helps people understand and respect differences in values and beliefs.
# Similarity Score: 0.15
#
# Query: How does mindfulness contribute to personal success?
# Original Response: Let's break down how mindfulness contributes to personal success, step by step:
#
# **Step 1: Increased Self-Awareness**
# Mindfulness helps you develop a greater understanding of yourself, including your thoughts, emotions, strengths, and weaknesses. By being more aware of these internal factors, you can make better decisions that align with your values and goals.
#
# **Step 2: Reduced Stress and Anxiety**
# When you're mindful, you're better equipped to manage stress and anxiety, which are major obstacles to success. By learning to calm your mind and body, you can focus on the present moment and tackle challenges more effectively.
#
# **Step 3: Improved Focus and Concentration**
# Mindfulness improves your ability to concentrate and stay focused on long-term goals. This allows you to prioritize tasks, manage time more efficiently, and make progress towards achieving success.
#
# **Step 4: Enhanced Creativity and Problem-Solving Skills**
# By cultivating a mindful state, you can tap into your creative potential and develop innovative solutions to complex problems. This is essential for navigating the challenges that often accompany personal success.
#
# **Step 5: Better Relationships and Communication**
# Mindfulness helps you become more empathetic, understanding, and compassionate towards others. This, in turn, leads to stronger, more meaningful relationships with family, friends, and colleagues – all of which are crucial for achieving personal success.
#
# **Step 6: Increased Resilience and Adaptability**
# When faced with setbacks or failures, a mindful individual is better equipped to bounce back and adapt to changing circumstances. This resilience enables you to learn from mistakes, adjust your approach, and stay on the path to success.
#
# By understanding these six steps, it's clear that mindfulness plays a vital role in contributing to personal success by fostering self-awareness, reducing stress and anxiety, improving focus and concentration, enhancing creativity and problem-solving skills, promoting better relationships and communication, and increasing resilience and adaptability.
# Surrogate Response: Collaboration fosters creativity by combining diverse ideas and perspectives.
# Similarity Score: 0.17
#
# Query: Why is self-reflection important in personal growth?
# Original Response: Let's break down why self-reflection is crucial for personal growth.
#
# **Step 1: Identifying Blind Spots**
# Self-reflection helps you become aware of your thought patterns, emotions, and behaviors that may be hindering your progress or causing harm to yourself or others. By acknowledging these "blind spots," you can take steps to address them and make positive changes in your life.
#
# **Step 2: Gaining Insight into Values and Goals**
# Self-reflection allows you to examine your core values and goals, helping you understand what drives you and what you want to achieve. This clarity enables you to set meaningful objectives and prioritize your time and energy accordingly.
#
# **Step 3: Recognizing Patterns and Habits**
# Reflecting on your experiences helps you identify patterns and habits that may be holding you back or causing stagnation. By acknowledging these patterns, you can work on breaking them and developing more constructive behaviors.
#
# **Step 4: Fostering Accountability and Responsibility**
# Self-reflection promotes accountability and responsibility by encouraging you to examine your actions and their consequences. This introspection helps you develop a sense of ownership and take charge of your life's direction.
#
# **Step 5: Cultivating Self-Awareness and Humility**
# Through self-reflection, you cultivate a deeper understanding of yourself, which includes recognizing both strengths and weaknesses. This self-awareness allows you to approach challenges with humility, openness to learning, and a willingness to adapt.
#
# In summary, self-reflection is essential for personal growth because it helps you:
#
# * Identify blind spots and address them
# * Gain insight into your values and goals
# * Recognize patterns and habits that need improvement
# * Foster accountability and responsibility
# * Cultivate self-awareness and humility
#
# By embracing self-reflection, you'll be better equipped to navigate life's challenges, make informed decisions, and continue growing as an individual.
# Surrogate Response: Historical preservation ensures that the cultural and historical legacy is maintained.
# Similarity Score: 0.12
#
# Query: How can you overcome procrastination?
# Original Response: Overcoming procrastination indeed requires a strategic approach. Here are some steps to help you overcome procrastination:
#
# 1.  **Acknowledge and accept your procrastination**: The first step is to admit that you procrastinate and acknowledge its impact on your life. Recognize the feelings of guilt, anxiety, or frustration that come with putting things off.
#
# 2.  **Identify the reasons behind your procrastination**: Understanding why you put things off is crucial. Are you avoiding a task because it seems too difficult? Do you feel overwhelmed by deadlines or expectations? Once you identify the root cause, you can develop strategies to address these issues.
#
# 3.  **Break down tasks into smaller steps**: Divide large tasks into manageable chunks. This approach makes the task less intimidating and allows you to focus on one step at a time. As you complete each small task, you'll feel a sense of accomplishment and momentum.
#
# 4.  **Create a schedule and stick to it**: Set specific times for working on your tasks. Allocate dedicated blocks of time to avoid procrastination. Be realistic about how much you can accomplish in a day or week.
#
# 5.  **Use the Pomodoro Technique**: This technique involves working in focused, 25-minute increments, followed by a five-minute break. After four cycles, take a longer break of 15-30 minutes. This approach helps maintain focus and avoid burnout.
#
# 6.  **Eliminate distractions**: Identify common distractions (social media, email, phone notifications) and eliminate them while you work. Use tools like website blockers or apps that help you stay focused.
#
# 7.  **Reward yourself**: Set small rewards for achieving milestones. This positive reinforcement can motivate you to stay on track and enjoy the process of completing tasks.
#
# 8.  **Seek accountability**: Share your goals and progress with a friend or family member. Regularly report back to them, which can help you stay committed and motivated.
#
# 9.  **Practice self-compassion**: Be kind to yourself when you make mistakes or encounter setbacks. Don't give up! Instead, learn from these experiences and adjust your approach as needed.
#
# 10. **Celebrate your progress**: Acknowledge and celebrate the small victories along the way. This will help you stay motivated and encouraged throughout your journey.
#
# Remember that overcoming procrastination is a process, and it might take some experimentation to find the right combination of strategies that work for you. Be patient with yourself, and don't hesitate to seek support when needed.
# Surrogate Response: Navigating workplace politics requires diplomacy, tact, and communication skills.
# Similarity Score: 0.08
#
# Query: What role does resilience play in achieving success?
# Original Response: Let's break down the role of resilience in achieving success, step by step.
#
# **Step 1: Definition and Understanding**
# Resilience refers to the ability to withstand or recover quickly from difficult situations, challenges, or setbacks. It involves coping with stress, adapting to change, and bouncing back from adversity.
#
# **Step 2: Connection to Success**
# Research has shown that resilience is a key factor in achieving success. People who are resilient tend to:
# 	* Perform better under pressure
# 	* Bounce back faster from failures and setbacks
# 	* Adapt more easily to changing circumstances
# 	* Maintain motivation and confidence, even in the face of obstacles
#
# **Step 3: Overcoming Obstacles**
# Resilience helps individuals overcome obstacles that might otherwise hinder their progress towards success. By developing coping strategies and a growth mindset, resilient people can:
# 	* Learn from failures and mistakes
# 	* Regain momentum after setbacks
# 	* Stay focused on long-term goals despite short-term challenges
#
# **Step 4: Building Confidence and Motivation**
# As individuals develop resilience, they build confidence in their ability to handle difficult situations. This confidence boosts motivation, enabling them to take risks, pursue opportunities, and push through challenges that might have previously seemed insurmountable.
#
# **Step 5: Sustainability of Success**
# Resilience is not a one-time achievement; it's an ongoing process. By cultivating resilience, individuals can sustain their success over time, even as circumstances change or new obstacles arise.
#
# In conclusion, resilience plays a critical role in achieving success by:
# 	* Enhancing coping skills and adaptability
# 	* Building confidence and motivation
# 	* Overcoming obstacles and setbacks
# 	* Sustaining progress towards long-term goals
#
# By developing resilience, individuals can unlock their full potential and achieve greater success in all areas of life.
# Surrogate Response: Collaboration fosters creativity by combining diverse ideas and perspectives.
# Similarity Score: 0.11
#
# Query: How can journaling help in self-improvement?
# Original Response: Let's break down how journaling can aid in self-improvement:
#
# **Step 1: Reflection and Awareness**
# Journaling helps you reflect on your thoughts, feelings, and experiences. By writing down your insights, you become more aware of patterns, emotions, and behaviors that influence your life. This increased awareness is the foundation for making positive changes.
#
# **Step 2: Identifying Goals and Aspirations**
# Through journaling, you can identify areas where you'd like to improve or grow. Writing down specific goals and aspirations helps clarify what you want to achieve in various aspects of your life, such as relationships, career, or personal growth.
#
# **Step 3: Tracking Progress and Accountability**
# By regularly recording your progress toward your goals, journaling provides a sense of accountability. You can track successes, setbacks, and lessons learned, which motivates you to stay on course and make adjustments as needed.
#
# **Step 4: Self-Discovery and Mindfulness**
# Journaling encourages self-reflection and mindfulness, helping you tune into your inner world and emotions. This introspection fosters a deeper understanding of yourself, including your strengths, weaknesses, values, and priorities.
#
# **Step 5: Building Confidence and Self-Esteem**
# As you reflect on your accomplishments and progress, journaling can help boost your confidence and self-esteem. Celebrating small victories and acknowledging your growth can inspire you to tackle new challenges and strive for excellence.
#
# **Step 6: Developing a Growth Mindset**
# By embracing the process of learning and improvement through journaling, you cultivate a growth mindset. This mindset allows you to view failures and setbacks as opportunities for growth, rather than threats to your ego.
#
# In summary, journaling is a powerful tool for self-improvement because it:
#
# * Enhances reflection and awareness
# * Helps set clear goals and aspirations
# * Facilitates progress tracking and accountability
# * Encourages self-discovery and mindfulness
# * Boosts confidence and self-esteem
# * Fosters a growth mindset
#
# By incorporating journaling into your daily or weekly routine, you can unlock the potential for personal growth and self-improvement.
# Surrogate Response: Collaboration fosters creativity by combining diverse ideas and perspectives.
# Similarity Score: 0.15
#
# Query: What is the impact of setting SMART goals?
# Original Response: Let's break down the impact of setting SMART goals step by step.
#
# **S - Specific**: When a goal is specific, it clearly defines what needs to be accomplished. This helps in focusing efforts and resources towards achieving that specific outcome.
#
# Impact:
#
# * **Reduced ambiguity**: Specificity eliminates confusion about what needs to be done.
# * **Increased clarity**: Goals are well-defined, making it easier for individuals to understand what's expected of them.
# * **Improved focus**: People can concentrate on a clear objective without getting sidetracked by irrelevant tasks or activities.
#
# **M - Measurable**: When goals are measurable, progress toward achieving them can be tracked and monitored. This facilitates adjustments to strategies as needed.
#
# Impact:
#
# * **Enhanced accountability**: Goals are tied to specific metrics, making it easier for individuals to report on their progress.
# * **Better tracking of performance**: Performance indicators allow for regular assessments of how far along one has progressed toward meeting the goal.
# * **Informed decision-making**: Data from measurable goals help in identifying areas that need improvement and informing future planning.
#
# **A - Achievable (Attainable)**: Setting achievable goals ensures they're realistic, taking into account available resources and constraints. This encourages motivation without discouragement due to impossibility.
#
# Impact:
#
# * **Boosted motivation**: Goals are set at a level where success seems possible and thus achievable.
# * **Prevention of demotivation**: Unrealistic expectations can lead to disappointment; setting achievable goals maintains interest and enthusiasm in the endeavor.
# * **Resource optimization**: Resources are utilized effectively as they're applied towards realistic objectives.
#
# **R - Relevant**: When goals align with an individual's values, needs, or priorities, they become meaningful and motivating. This relevance fosters engagement and commitment toward achieving the goal.
#
# Impact:
#
# * **Personal alignment**: Goals align with personal interests or values, making them more appealing and thusly achievable.
# * **Increased motivation**: The relevance of a goal makes it more desirable to pursue.
# * **Better use of time and resources**: Resources are used effectively as they're directed towards goals that have personal significance.
#
# **T - Time-bound**: Setting deadlines for achieving goals provides a sense of urgency, encouraging individuals to take timely action. This helps in prioritizing tasks efficiently.
#
# Impact:
#
# * **Promotes efficiency**: Prioritization is improved as tasks are focused on the most urgent ones first.
# * **Boosts motivation**: A time limit creates pressure that motivates individuals toward quicker completion of objectives.
# * **Prevents procrastination**: Knowing the deadline encourages timely action rather than putting things off until later.
#
# Setting SMART goals has a profound impact on personal and professional achievement. It improves focus, efficiency, motivation, accountability, resource optimization, and prioritization.
# Surrogate Response: Historical preservation ensures that the cultural and historical legacy is maintained.
# Similarity Score: 0.11
#
# Query: Why is lifelong learning important for personal growth?
# Original Response: Let's break down the importance of lifelong learning for personal growth, step by step.
#
# **Step 1: Staying Up-to-Date with a Changing World**
# The world around us is constantly changing. New technologies emerge every day, and old methods become outdated. To navigate this fast-paced environment effectively, we need to stay informed and adaptable. Lifelong learning allows us to keep abreast of these changes, ensuring that our skills are relevant in the modern job market or for personal interests.
#
# **Step 2: Enhancing Career Opportunities**
# In today's competitive job market, employers seek individuals who possess not only theoretical knowledge but also practical experience and continuous learning habits. Engaging in lifelong learning can open up new career paths or enhance existing ones by acquiring specialized skills that are highly valued by the industry.
#
# **Step 3: Improving Personal Skills and Competence**
# Personal growth is about becoming a better version of ourselves, both professionally and personally. Through lifelong learning, we can improve our communication, problem-solving, and critical thinking skills. These are essential for personal success and can lead to better decision-making in various aspects of life.
#
# **Step 4: Encouraging Creativity and Innovation**
# Engaging in continuous learning exposes us to diverse ideas, perspectives, and experiences that can stimulate creativity. This is crucial for innovation within both professional and personal projects. By constantly seeking knowledge and understanding new concepts, we open ourselves up to a world of possibilities, fostering growth through novel approaches and solutions.
#
# **Step 5: Building Confidence and Self-Efficacy**
# The process of learning itself has a profound impact on our self-confidence. As we successfully navigate learning experiences, our perception of what we can accomplish grows. This confidence boost extends beyond the confines of education into other areas of life, making us more resilient in the face of challenges.
#
# **Step 6: Fostering Personal Development and Autonomy**
# Ultimately, lifelong learning is a powerful tool for personal development. It allows individuals to set their own goals based on interests rather than external pressures. Through this process, we develop autonomy over our lives, deciding how and where we apply our knowledge in the pursuit of happiness and fulfillment.
#
# In conclusion, lifelong learning is not merely about academic or professional advancement; it's a journey towards personal growth, empowerment, and self-improvement. By embracing continuous learning, we not only adapt to a changing world but also foster confidence, innovation, and autonomy. This path leads us toward realizing our full potential and living life on our own terms.
# Surrogate Response: Historical preservation ensures that the cultural and historical legacy is maintained.
# Similarity Score: 0.14
#
# Query: How do you develop a growth mindset?
# Original Response: Developing a growth mindset is a wonderful goal, and I'd be happy to guide you through it step by step.
#
# **Step 1: Understand the Concept**
# A growth mindset is the understanding that your abilities and intelligence can be developed through dedication, hard work, persistence, and learning from failures. It's the opposite of a fixed mindset, which believes that your abilities are innate and cannot be changed.
#
# **Step 2: Identify Your Fixed Mindset Patterns**
# Take some time to reflect on your thoughts and behaviors when faced with challenges or setbacks. Do you:
# 	* Give up easily when things don't go as planned?
# 	* Get discouraged by criticism or feedback?
# 	* Believe that success is only for a select few, and not achievable by others?
# 	* Think that you're either naturally good at something or not?
#
# **Step 3: Learn to Embrace Challenges**
# Instead of avoiding challenges, view them as opportunities for growth. Ask yourself:
# 	* What can I learn from this experience?
# 	* How can I improve my skills in this area?
# 	* What would happen if I tried a different approach?
#
# **Step 4: Focus on Effort, Not Just Talent**
# Recognize that success is often the result of consistent effort and dedication, rather than just natural talent. Celebrate your progress, no matter how small.
#
# **Step 5: Develop a Learning Orientation**
# Focus on learning from mistakes and failures. Ask yourself:
# 	* What did I learn from this experience?
# 	* How can I apply what I learned to future situations?
# 	* What steps can I take to improve my performance next time?
#
# **Step 6: Surround Yourself with Positive Influences**
# Surround yourself with people who support your growth mindset, and avoid those who might discourage or criticize you.
#
# **Step 7: Practice Self-Compassion**
# Treat yourself with kindness and understanding when faced with challenges. Remind yourself that everyone makes mistakes, and it's okay to take time to learn and grow.
#
# By following these steps, you'll be well on your way to developing a growth mindset. Remember, it takes time and practice, but the benefits are worth it!
#
# What do you think? Is there anything in particular that resonates with you or something you'd like to add?
# Surrogate Response: Navigating workplace politics requires diplomacy, tact, and communication skills.
# Similarity Score: 0.08
#
# Query: How do you resolve conflicts within a team?
# Original Response: Resolving conflicts within a team can be challenging, but it's an essential skill for any effective leader or team member to master. Here's a step-by-step guide on how to resolve conflicts within a team:
#
# **Step 1: Acknowledge and Address the Conflict**
#
# * Recognize that a conflict exists and take steps to address it as soon as possible.
# * Encourage team members to express their concerns and feelings openly.
#
# **Step 2: Gather Information**
#
# * Talk to each party involved in the conflict to understand their perspective.
# * Ask questions like "What happened?" "How do you feel about this situation?" and "What do you think should be done?"
#
# **Step 3: Identify the Root Cause of the Conflict**
#
# * Analyze the information gathered to identify the underlying cause(s) of the conflict.
# * Consider factors such as communication breakdowns, misunderstandings, or differing values.
#
# **Step 4: Involve Key Stakeholders (Optional)**
#
# * If necessary, involve other team members who can provide valuable input and help resolve the issue.
# * Encourage diverse perspectives to ensure a comprehensive understanding of the situation.
#
# **Step 5: Foster an Open Discussion**
#
# * Create a safe and neutral environment for open discussion among team members.
# * Encourage active listening, empathy, and respect for each other's opinions.
#
# **Step 6: Find Common Ground (or Alternatives)**
#
# * Help team members identify areas of agreement and common goals.
# * Look for alternative solutions that satisfy the needs of all parties involved.
#
# **Step 7: Agree on a Resolution**
#
# * Once a resolution is reached, ensure it aligns with the team's values and goals.
# * Encourage each team member to take ownership of their role in implementing the agreed-upon solution.
#
# **Step 8: Monitor Progress and Adjust as Needed**
#
# * Regularly check-in with the team to monitor progress and address any further issues that arise.
# * Be prepared to make adjustments if necessary, to ensure the resolution remains effective.
#
# By following these steps, you can help your team resolve conflicts in a constructive and respectful manner. Remember, conflict resolution is an ongoing process that requires effort and dedication from all parties involved.
# Surrogate Response: Navigating workplace politics requires diplomacy, tact, and communication skills.
# Similarity Score: 0.08
#
# Query: What are the qualities of a good leader?
# Original Response: A question that has been debated and explored by many experts, philosophers, and leaders themselves!
#
# To identify the qualities of a good leader, let's break down the process into several steps:
#
# **Step 1: Understanding Leadership**
#
# Leadership is about inspiring and guiding others towards a common goal or vision. A good leader motivates, empowers, and enables their team to achieve success.
#
# **Step 2: Identifying Key Characteristics**
#
# Research and experience have shown that effective leaders often possess certain key characteristics, including:
#
# 1. **Integrity**: Demonstrating high moral standards and ethics.
# 2. **Vision**: Having a clear understanding of the organization's mission, values, and goals.
# 3. **Communication**: Effectively conveying ideas, listening actively, and clarifying expectations.
# 4. **Empathy**: Showing compassion, understanding, and respect for others' perspectives.
# 5. **Courage**: Taking calculated risks, facing challenges head-on, and making tough decisions.
# 6. **Adaptability**: Being open to change, learning from mistakes, and adjusting plans as needed.
# 7. **Self-awareness**: Understanding their own strengths, weaknesses, biases, and emotions.
#
# **Step 3: Considering Situational Factors**
#
# Good leaders also consider the context and circumstances of their team and organization:
#
# 1. **Cultural awareness**: Recognizing and valuing diversity, promoting inclusivity, and adapting to different cultural backgrounds.
# 2. **Emotional intelligence**: Managing one's own emotions and empathizing with others'.
# 3. **Flexibility**: Adjusting leadership style to suit the needs of various stakeholders.
#
# **Step 4: Reflecting on Personal Qualities**
#
# Effective leaders continuously reflect on their personal qualities:
#
# 1. **Self-reflection**: Regularly evaluating strengths, weaknesses, values, and goals.
# 2. **Learning**: Embracing growth opportunities, seeking feedback, and applying new knowledge.
# 3. **Accountability**: Taking ownership of actions, decisions, and outcomes.
#
# **Step 5: Integrating Qualities into Leadership**
#
# Ultimately, a good leader integrates these qualities into their leadership practice:
#
# 1. **Practicing what they preach**: Living up to the values and principles they advocate for others.
# 2. **Empowering teams**: Creating an environment that fosters collaboration, trust, and autonomy.
# 3. **Fostering growth**: Encouraging learning, innovation, and experimentation.
#
# By considering these steps, we can conclude that a good leader embodies a unique combination of qualities, skills, and traits that inspire and guide others towards achieving success.
# Surrogate Response: Cultural competency helps people understand and respect differences in values and beliefs.
# Similarity Score: 0.28
#
# Query: How do you build trust among team members?
# Original Response: Building trust among team members is crucial for a harmonious, productive, and effective work environment. Here's a step-by-step guide to help you achieve this:
#
# ### 1. **Lead by Example**
# - **Demonstrate Integrity**: Show the team what it means to be honest and transparent in your actions and decisions. If you promise something, follow through on it.
# - **Be Accountable**: Take responsibility for your mistakes and own up to them. This shows that you value trustworthership.
# - **Communicate Clearly and Openly**: Share information, listen actively, and ensure the team feels included in discussions about the project's goals and processes.
#
# ### 2. **Empower Your Team Members**
# - **Trust Their Abilities**: Give tasks that challenge team members and allow them to learn from their experiences.
# - **Provide Resources**: Ensure they have all necessary tools, training, and support to excel.
# - **Involve Them in Decision-Making**: When appropriate, involve the team in making decisions related to their work. This shows that you value their input.
#
# ### 3. **Foster Open Communication**
# - **Regular Meetings**: Hold regular meetings where everyone's voice is heard. Use these opportunities to discuss challenges and successes.
# - **Encourage Feedback**: Create a safe environment where team members feel comfortable sharing feedback, both positive and constructive, about each other's work.
# - **Listen Actively**: Pay attention when others are speaking, especially in situations where people might feel nervous or uncomfortable sharing their thoughts.
#
# ### 4. **Celebrate Successes**
# - **Acknowledge Contributions**: Recognize and reward team members' contributions to the project's success.
# - **Publicly Praise**: Publicly praise team members for their achievements on the project.
# - **Learn from Mistakes**: If mistakes occur, use them as learning opportunities. This demonstrates that you value growth over perfection.
#
# ### 5. **Consistency**
# - **Set Clear Expectations**: Establish clear expectations and then maintain consistency in how these expectations are managed.
# - **Follow Through**: Consistently follow through on commitments to show the team that their time is valuable and respected.
#
# Building trust among team members takes time, effort, and a genuine commitment to your team's growth. By following these steps, you can create an environment where people feel valued, heard, and supported in achieving the project’s goals.
# Surrogate Response: Navigating workplace politics requires diplomacy, tact, and communication skills.
# Similarity Score: 0.09
#
# Query: What are the key principles of servant leadership?
# Original Response: Servant leadership is a leadership philosophy that emphasizes serving others, putting their needs and interests first, and leading in a way that benefits everyone involved. Here are the key principles of servant leadership:
#
# 1. **Prioritize people over profits**: Servant leaders put the well-being and growth of their team members above the bottom line. They recognize that happy employees lead to customer satisfaction, which ultimately drives business success.
# 2. **Listen more than you speak**: Effective listening is a crucial aspect of servant leadership. Leaders should listen actively, ask questions, and clarify expectations to ensure they understand their people's needs.
# 3. **Empower others**: Servant leaders empower their team members by giving them the autonomy to make decisions, take ownership, and work towards shared goals. This approach fosters trust, motivation, and collaboration.
# 4. **Foster a culture of gratitude**: A servant leader acknowledges and appreciates the efforts of their team members, creating a positive work environment where people feel valued and motivated to contribute.
# 5. **Lead by example**: Servant leaders set the tone for their organization by demonstrating the behaviors they expect from others. They model accountability, integrity, and a willingness to learn and grow.
# 6. **Be humble**: Humility is essential in servant leadership. Leaders should be willing to admit when they don't know something, seek input from others, and avoid positional power trips.
# 7. **Practice empathy**: Servant leaders understand that everyone has unique perspectives, experiences, and challenges. They strive to empathize with their team members, creating a safe space for open communication and collaboration.
# 8. **Focus on the present moment**: Servant leaders remain grounded in the present, addressing immediate needs and opportunities rather than getting caught up in past regrets or future anxieties.
# 9. **Celebrate successes**: Servant leaders recognize and celebrate the achievements of their team members, no matter how small they may seem. This approach reinforces positive behaviors and motivates others to strive for excellence.
# 10. **Embody a growth mindset**: Servant leaders are committed to continuous learning and growth, both personally and professionally. They encourage their team members to do the same, creating a culture of innovation and improvement.
#
# By embracing these principles, servant leaders can create a positive, productive work environment where everyone thrives.
# Surrogate Response: Cultural competency helps people understand and respect differences in values and beliefs.
# Similarity Score: 0.20
#
# Query: How does diversity improve teamwork?
# Original Response: Let's break down how diversity improves teamwork:
#
# 1. **Unique Perspectives**: A team with diverse members brings together individuals with different backgrounds, experiences, and ways of thinking. This leads to a broader range of perspectives on problems and issues, making it easier for the team to come up with innovative solutions.
#
# 2. **Improved Communication**: Diversity in a team can also foster improved communication as people learn about and appreciate different cultures, customs, and methods of expression. This creates an environment where everyone feels comfortable sharing their thoughts and ideas, which is essential for effective teamwork.
#
# 3. **Problem-Solving Skills Enhanced**: The variety of perspectives on a problem allows teams to attack it from multiple angles simultaneously. This can lead to quicker identification of potential solutions and more comprehensive approaches to solving complex problems.
#
# 4. **Innovation and Creativity**: Diversity within a team leads to a more diverse set of ideas, which is key for innovation and creativity in the workplace. When individuals with different perspectives come together, they bring unique insights that can help solve complex problems or create new products/services.
#
# 5. **Better Representation of Customer Needs**: If your team's diversity mirrors the demographics of your customer base, then you have a better understanding of their needs and preferences. This not only helps in marketing but also ensures that the final product meets the expectations of various segments of your target market.
#
# 6. **Enhanced Reputation**: Organizations known for their diversity are more likely to attract diverse customers, suppliers, and employees. This can improve the company's reputation, making it more attractive to potential partners, investors, or top talent in the industry.
#
# 7. **Access to a Broader Talent Pool**: Diversity within an organization opens up access to a broader pool of talented individuals who might be interested in working for companies that value diversity and inclusivity. This can help attract the best candidates and reduce turnover rates, saving costs associated with training and recruitment.
#
# 8. **Long-Term Sustainability**: In today's globalized economy, businesses need to consider not just short-term gains but also their long-term sustainability. A diverse team is more likely to make decisions that are sustainable in the long term because it reflects a broader understanding of various stakeholders' needs and perspectives.
#
# In conclusion, diversity plays a crucial role in improving teamwork by enhancing unique perspectives, communication, problem-solving skills, innovation, creativity, better representation of customer needs, reputation, access to talent, and ultimately leading to long-term sustainability.
# Surrogate Response: Collaboration fosters creativity by combining diverse ideas and perspectives.
# Similarity Score: 0.17
#
# Query: What are effective techniques for motivating a team?
# Original Response: Effective techniques for motivating a team can be broken down into several steps:
#
# 1. **Set Clear Goals and Expectations**: Clearly define the team's purpose, objectives, and expectations. This helps create a sense of direction and motivation.
#
# 2. **Encourage Open Communication**: Foster an environment where all team members feel comfortable sharing their thoughts, ideas, and concerns. Active listening is key to ensuring that everyone feels heard and valued.
#
# 3. **Recognize and Reward Efforts and Achievements**: Regularly acknowledge and reward the contributions and successes of each team member. This can be through public recognition, bonuses, or other forms of appreciation.
#
# 4. **Empower Team Members**: Give team members autonomy over their work. Encourage them to take ownership of projects and decisions, making sure they have the necessary resources and support.
#
# 5. **Foster a Positive Work Environment**: Promote a culture that is positive, inclusive, and respectful. Celebrate successes, learn from failures, and maintain open lines of communication.
#
# 6. **Provide Opportunities for Growth and Development**: Offer training, mentorship, and opportunities for professional development to help team members grow both personally and professionally.
#
# 7. **Lead by Example**: Leaders should demonstrate the behaviors and values they expect from their team. This includes being transparent, approachable, and committed to shared goals.
#
# 8. **Conduct Regular Feedback Sessions**: Hold regular meetings or sessions where team members can provide feedback on various aspects of the team's work and dynamics. This helps in identifying areas for improvement and ensuring that everyone is working towards a common goal.
#
# 9. **Celebrate Milestones and Successes**: Acknowledge significant events, milestones, and achievements within the team. Celebrating these moments strengthens bonds and reinforces the sense of accomplishment.
#
# 10. **Emphasize Work-Life Balance**: Encourage team members to maintain a balance between their work life and personal life. This can lead to higher job satisfaction and motivation.
#
# By implementing these techniques, you can create an environment that fosters motivation within your team, leading to increased productivity, job satisfaction, and overall success of the organization.
# Surrogate Response: Cultural competency helps people understand and respect differences in values and beliefs.
# Similarity Score: 0.26
#
# Query: How do you handle criticism as a team leader?
# Original Response: Handling criticism as a team leader can be challenging, but it's an essential skill to develop for effective leadership and growth. Here's a step-by-step guide on how to handle criticism:
#
# **Step 1: Remain Calm and Composed**
#
# When faced with criticism, it's natural to feel defensive or emotional. However, as a team leader, it's crucial to remain calm and composed. Take a moment to collect your thoughts before responding.
#
# **Step 2: Listen Actively**
#
# Listen carefully to the feedback being provided. Pay attention to specific concerns, issues, or suggestions. Avoid interrupting or becoming dismissive, even if you disagree with some points. Show that you value the person's input and are willing to listen.
#
# **Step 3: Acknowledge and Validate**
#
# Acknowledge the criticism and show appreciation for the person's willingness to provide feedback. Validate their concerns by acknowledging the effort they put into sharing their thoughts.
#
# Example: "Thank you for taking the time to share your thoughts on this matter. I appreciate your honest feedback."
#
# **Step 4: Clarify and Seek Understanding**
#
# Clarify any misunderstandings or areas of confusion. Ask questions to gain a deeper understanding of the person's perspective. This demonstrates that you're committed to learning and growth.
#
# Example: "Can you help me understand why you feel this way? What specific concerns do you have?"
#
# **Step 5: Evaluate and Reflect**
#
# Take time to evaluate the criticism, considering both positive and negative feedback. Reflect on your actions, decisions, or behaviors that may have led to the criticism.
#
# **Step 6: Respond Thoughtfully**
#
# Respond thoughtfully, addressing any concerns or issues raised. Be transparent about your thought process and decision-making. Show how you've taken their feedback into consideration when making changes or improvements.
#
# Example: "I appreciate your concern about X. I agree that we can improve in this area. We'll implement the following measures to address this issue."
#
# **Step 7: Follow Up**
#
# Follow up on any commitments made, ensuring that necessary actions are taken to address concerns raised by criticism. This demonstrates accountability and a commitment to growth.
#
# By following these steps, you'll be able to handle criticism effectively as a team leader, fostering a culture of openness, transparency, and continuous improvement within your organization.
# Surrogate Response: Navigating workplace politics requires diplomacy, tact, and communication skills.
# Similarity Score: 0.06
#
# Query: What are the characteristics of high-performing teams?
# Original Response: Let's break down the characteristics of high-performing teams step by step.
#
# **Step 1: Clear Goals and Expectations**
#
# High-performing teams have clear, well-defined goals and expectations that align with the overall vision and strategy of the organization. This clarity ensures everyone is working towards the same objectives and understands their role in achieving them.
#
# **Step 2: Strong Communication**
#
# Effective communication is essential for high-performing teams. Team members must be able to communicate openly, honestly, and respectfully with each other. They should feel comfortable sharing ideas, concerns, and feedback without fear of judgment or reprisal.
#
# **Step 3: Trust and Vulnerability**
#
# High-performing teams are built on trust. Team members feel safe taking risks, being vulnerable, and admitting mistakes. This environment fosters a sense of psychological safety, where individuals can speak up without fear of ridicule or retribution.
#
# **Step 4: Diversity, Inclusion, and Equity**
#
# The best teams have diverse perspectives, backgrounds, and experiences. They actively seek out different viewpoints, value individual differences, and strive for inclusivity and equity in decision-making processes.
#
# **Step 5: Continuous Learning and Development**
#
# High-performing teams prioritize learning and growth. They encourage continuous development, experimentation, and innovation. Members are empowered to take ownership of their skills and knowledge, and the team as a whole learns from successes and setbacks.
#
# **Step 6: Autonomy and Accountability**
#
# Effective teams have a balance between autonomy (the freedom to make decisions) and accountability (taking responsibility for those decisions). Team members should be trusted to make informed choices while still being held accountable for their actions.
#
# **Step 7: Positive Feedback Culture**
#
# High-performing teams maintain a positive feedback culture, focusing on what's working well rather than dwelling on mistakes. They recognize and celebrate individual and team achievements, reinforcing behaviors that contribute to success.
#
# By incorporating these characteristics, high-performing teams can achieve remarkable results, drive innovation, and create a sustainable competitive advantage in their respective industries.
#
# What specific aspect of high-performing teams would you like me to elaborate on?
# Surrogate Response: Cultural competency helps people understand and respect differences in values and beliefs.
# Similarity Score: 0.23
#
# Query: How can team-building activities improve productivity?
# Original Response: Let's break down how team-building activities can improve productivity step by step:
#
# **Step 1: Building Trust and Communication**
#
# When team members participate in team-building activities, they start to develop trust among themselves. This is because they're interacting with each other in a relaxed and informal setting, allowing them to get to know one another's personalities, strengths, and weaknesses. As trust grows, communication improves, and team members become more comfortable sharing their ideas and concerns.
#
# **Step 2: Fostering Collaboration**
#
# ...
# Rituals associated with traditions reinforce societal values by creating emotional connections between community members and the values themselves. These rituals often involve shared experiences that evoke feelings of nostalgia, pride, or belonging.
#
# By considering these steps, it's clear that traditions play a significant role in shaping societal values. They provide a foundation for cultural identity, social norms, and community cohesion, which ultimately contribute to the development and evolution of societal values over time.
# Surrogate Response: Navigating workplace politics requires diplomacy, tact, and communication skills.
# Similarity Score: 0.07
#
# Query: What are strategies for effective public speaking?
# Original Response: Effective public speaking is a crucial skill that can be developed with practice and the right strategies. Here are some key strategies to consider:
#
# 1. **Know Your Audience**: Before preparing your speech, try to understand who you're addressing. What are their needs? What are they interested in? Tailor your message accordingly.
#
# 2. **Prepare Thoroughly**: Make sure you have a clear understanding of the topic and can express it confidently. Practice your delivery several times until you feel comfortable with the material.
#
# 3. **Use Strong, Clear Language**: Avoid using jargon or complex terminology that might confuse your audience. Use simple, direct language to get your message across effectively.
#
# 4. **Organize Your Content**: Structure your speech with an introduction, body, and conclusion. Make sure each point flows logically into the next for easy understanding.
#
# 5. **Make Eye Contact**: Engage with your audience by maintaining eye contact throughout your speech. This shows you respect them and are confident in what you're saying.
#
# 6. **Use Body Language Effectively**: Your posture, facial expressions, and gestures can all convey confidence and enthusiasm for your topic. Practice good body language to enhance your delivery.
#
# 7. **Practice Your Delivery**: Practice speaking before a mirror or with friends. This will help you feel comfortable with the content and confident in your presentation style.
#
# 8. **Use Visual Aids Wisely**: If appropriate, use visual aids like slides, videos, or props to support your message and make it more engaging. Make sure they are not distracting but rather enhance your points.
#
# 9. **Listen to Feedback**: After delivering a speech, be open to feedback from others. Use this to improve future speeches by learning what works well and where adjustments might need to be made.
#
# 10. **Keep Learning**: Public speaking is an ongoing process of improvement. Continuously practice, receive feedback, and seek out new techniques or strategies to become even more effective in your communication skills.
#
# Remember, public speaking is a skill that takes time and effort to develop. With consistent practice and a willingness to improve, you can become a confident and effective public speaker.
# Surrogate Response: Cultural competency helps people understand and respect differences in values and beliefs.
# Similarity Score: 0.14
#
# Query: How does gratitude enhance personal happiness?
# Original Response: Let's break down the relationship between gratitude and personal happiness, step by step.
#
# **Step 1: Focus on the positive**
# When we focus on what we're grateful for, our attention shifts from what's lacking to what already exists in our lives. This mindset helps us appreciate the good things, like supportive relationships, health, or personal accomplishments.
#
# **Step 2: Cultivate a sense of abundance**
# Gratitude fosters a feeling of abundance, even when we don't have everything we want. It reminds us that there's always something to be thankful for, making us feel more content and less entitled.
#
# **Step 3: Encourage positive emotions**
# Expressing gratitude releases endorphins, also known as "feel-good" hormones. This natural high helps us experience joy, calmness, and relaxation, all of which contribute to a sense of happiness.
#
# **Step 4: Strengthen relationships**
# Gratitude can bring people closer together by fostering empathy and appreciation for one another. When we show gratitude towards others, they're more likely to reciprocate, creating stronger bonds and social connections that enhance overall happiness.
#
# **Step 5: Promote self-awareness and self-reflection**
# Practicing gratitude helps us reflect on our experiences, values, and goals. This introspection can lead to a deeper understanding of ourselves and what truly brings us joy, allowing us to make positive changes in our lives.
#
# **Step 6: Develop resilience and optimism**
# Gratitude can help us bounce back from setbacks by focusing on the good that's still present, even in difficult situations. A grateful mindset also promotes optimism, enabling us to look forward to a brighter future with hope and enthusiasm.
#
# By following these steps, we can see how gratitude enhances personal happiness by promoting a positive outlook, fostering strong relationships, and encouraging self-awareness and growth.
# Surrogate Response: Collaboration fosters creativity by combining diverse ideas and perspectives.
# Similarity Score: 0.12
#
# Query: What is the significance of non-verbal communication?
# Original Response: Let's break down the significance of non-verbal communication step by step.
#
# **1. Complementing Verbal Communication**: Non-verbal cues, such as body language (e.g., posture, facial expressions), tone of voice, and physical touch, complement verbal messages. They can clarify or contradict what is said verbally, making them essential for effective communication.
#
# **2. Enhancing Meaning**: Non-verbal signs can add depth and nuance to verbal messages, conveying emotions, attitudes, or intentions that might not be explicitly stated. For example, a smile can soften the impact of a negative message.
#
# **3. Facilitating Emotional Connection**: Non-verbal cues are essential for building rapport and establishing an emotional connection with others. Facial expressions, eye contact, and physical proximity can all contribute to a sense of warmth and trust.
#
# **4. Managing Conflict**: In conflict situations, non-verbal communication can be particularly important. It can help prevent escalation or resolve the issue more quickly by conveying empathy and understanding without needing words.
#
# **5. Influencing Perception**: Non-verbal cues can shape how others perceive us and our messages. A confident posture, for example, can convey self-assurance and competence, while a hesitant demeanor might suggest uncertainty.
#
# **6. Cross-Cultural Significance**: Non-verbal communication has different meanings in various cultures. Understanding these differences is crucial for successful cross-cultural interactions, where non-verbal cues can either facilitate or hinder effective communication.
#
# **7. Importance in Business and Professional Settings**: In professional settings, non-verbal communication can influence how others perceive our expertise, competence, and trustworthiness. It plays a significant role in negotiations, presentations, and interviews, among other contexts.
#
# In conclusion, the significance of non-verbal communication lies in its ability to complement verbal messages, enhance meaning, facilitate emotional connection, manage conflict, influence perception, have cross-cultural implications, and be crucial in business and professional settings.
# Surrogate Response: Historical preservation ensures that the cultural and historical legacy is maintained.
# Similarity Score: 0.11
#
# Query: How do hobbies contribute to personal growth?
# Original Response: Let's break down how hobbies can contribute to personal growth, step by step.
#
# **1. Building Confidence and Self-Esteem**: Engaging in a hobby can help you develop a sense of accomplishment and pride in your abilities. As you learn new skills and master techniques, you'll feel more confident in your capabilities, which can translate to other areas of life. This confidence boost can enhance self-esteem, making you feel more capable of tackling challenges.
#
# **2. Developing New Skills**: Hobbies often require learning new skills or techniques, such as playing a musical instrument, painting, or cooking. As you develop these skills, you'll become more proficient and independent. This process of skill-building can help you develop problem-solving skills, critical thinking, and creativity – all essential for personal growth.
#
# **3. Expanding Social Connections**: Many hobbies involve interacting with others who share similar interests, such as joining a book club, sports team, or art group. These social connections can lead to new friendships and relationships, which are vital for emotional support, networking, and personal growth.
#
# **4. Enhancing Creativity and Imagination**: Hobbies often tap into your creative side, allowing you to express yourself in unique ways. Engaging in activities that promote imagination and creativity can help you think outside the box, come up with innovative solutions, and approach problems from different perspectives – essential for personal growth and self-discovery.
#
# **5. Reducing Stress and Improving Mental Health**: Hobbies can provide a healthy distraction from daily stressors and anxiety. Activities like meditation, yoga, or spending time in nature can help calm the mind, reduce symptoms of depression, and promote overall mental well-being.
#
# **6. Building Resilience and Adaptability**: Engaging in hobbies that involve risk-taking, such as public speaking, performing, or competing, can help you develop resilience and adaptability. As you face challenges and setbacks, you'll learn to bounce back, reassess situations, and adjust your approach – valuable skills for navigating life's ups and downs.
#
# **7. Fostering Reflection and Self-Awareness**: Many hobbies involve introspection and self-reflection, such as journaling, writing, or photography. As you engage in these activities, you'll gain a deeper understanding of yourself, your values, and your goals – essential for personal growth and self-awareness.
#
# In conclusion, hobbies can contribute significantly to personal growth by building confidence, developing new skills, expanding social connections, enhancing creativity and imagination, reducing stress, building resilience, and fostering reflection and self-awareness. Engaging in activities you enjoy can help you become a more well-rounded, confident, and fulfilled individual – a true hallmark of personal growth!
# Surrogate Response: Navigating workplace politics requires diplomacy, tact, and communication skills.
# Similarity Score: 0.15
#
# Query: What are the benefits of reading fiction?
# Original Response: Let's break down the benefits of reading fiction step by step.
#
# **Step 1: Empathy and Understanding**
#
# Reading fiction helps us develop empathy and understanding towards others. By immersing ourselves in the experiences, emotions, and perspectives of fictional characters, we become more aware of the complexities of human relationships, motivations, and behaviors. This increased empathy can translate to our real-life interactions, making us more compassionate and tolerant individuals.
#
# **Step 2: Cognitive Development**
#
# Fiction reading stimulates cognitive development by challenging our minds to process new information, make connections between ideas, and solve problems. Through engaging storylines, characters' thought processes, and plot twists, readers develop their critical thinking skills, improve their memory, and enhance their analytical abilities.
#
# **Step 3: Emotional Intelligence**
#
# Reading fiction allows us to explore complex emotions in a safe and controlled environment. By witnessing the emotional journeys of fictional characters, we gain insight into our own emotions and learn how to navigate them more effectively. This increased emotional intelligence can lead to better relationships, improved mental health, and enhanced overall well-being.
#
# **Step 4: Social Connections**
#
# Reading fiction provides opportunities for social connections and community building. Joining book clubs, discussing favorite novels with friends, or participating in online forums centered around shared interests can help us meet like-minded individuals, build friendships, and feel a sense of belonging.
#
# **Step 5: Stress Relief and Relaxation**
#
# Finally, reading fiction offers a powerful stress-relief and relaxation mechanism. Losing ourselves in an engaging story can distract us from daily worries, promote a sense of calm, and even lower our blood pressure. This mental break can help us recharge, refocus, and return to our lives with renewed energy and purpose.
#
# In conclusion, the benefits of reading fiction are numerous and multifaceted. By exploring empathy, cognitive development, emotional intelligence, social connections, and stress relief, we can see how fiction reading can have a profound impact on our personal growth, relationships, and overall well-being.
# Surrogate Response: Cultural competency helps people understand and respect differences in values and beliefs.
# Similarity Score: 0.23
#
# Query: How does music influence emotions?
# Original Response: Let's break down the ways in which music can influence emotions, step by step.
#
# **Step 1: Personal Experience and Memories**
# Music often evokes memories and associations tied to specific experiences or periods of our lives. For example, hearing a song from your teenage years might transport you back to that time and evoke feelings associated with those memories (e.g., nostalgia, excitement). This personal connection is a powerful emotional trigger.
#
# **Step 2: Emotional Contagion**
# Music can create an emotional contagion effect, where the emotions expressed in a song are "caught" by listeners. When we hear music that evokes strong emotions (e.g., joy, sadness), our brain's emotional centers are activated, making us feel those same emotions.
#
# **Step 3: Neurological Response**
# Research has shown that music activates various areas of the brain associated with emotion regulation, such as the amygdala and prefrontal cortex. This neural response is similar to the one experienced during emotional experiences in real life (e.g., fear, excitement). The release of neurotransmitters like dopamine, serotonin, and endorphins can also contribute to emotional feelings.
#
# **Step 4: Contextual Factors**
# The context in which we experience music can influence its emotional impact. For example:
# 	* **Cultural background**: Music is often closely tied to cultural identity and traditions, which can shape our emotional response.
# 	* **Social situation**: Music can enhance or reduce emotions depending on the social setting (e.g., a romantic ballad might feel more intimate in a quiet, candlelit room).
# 	* **Emotional state**: Our current emotional state affects how we respond to music. When we're feeling anxious, for example, we might seek out calming music.
#
# **Step 5: Brain Processing and Memory Consolidation**
# Music's emotional impact can be reinforced through brain processing and memory consolidation. As we process music emotionally, our brain consolidates memories associated with those emotions, making them easier to recall in the future.
#
# In summary, music influences emotions by:
#
# 1. Evoking personal experiences and memories
# 2. Creating an emotional contagion effect
# 3. Activating neural centers involved in emotion regulation
# 4. Being influenced by contextual factors (culture, social situation, emotional state)
# 5. Reinforcing its impact through brain processing and memory consolidation
#
# These interconnected processes demonstrate how music can have a profound impact on our emotions, making it a powerful tool for expression, communication, and emotional exploration.
# Surrogate Response: Collaboration fosters creativity by combining diverse ideas and perspectives.
# Similarity Score: 0.07
#
# Responses have been stored in responses_comparison.json

# %%
import json

# Load the data from responses_comparison.json
with open("responses_comparison.json", "r") as f:
    results = json.load(f)

# Print the type and first item to inspect the data structure
print("Type of the loaded data:", type(results))
print("First item in the data:", results[0])  # Adjust this based on how many items are present
# Out:
# Type of the loaded data: <class 'list'>
# First item in the data: {'query': 'How can you improve your time management skills?', 'original_response': 'Improving time management skills requires a strategic approach. Here are some steps to help you achieve better time management:\n\n1. **Set Clear Goals**: Establishing specific, measurable, achievable, relevant, and time-bound (SMART) goals helps you focus on what\'s important. Break down large objectives into smaller tasks to maintain momentum.\n\n2. **Track Your Time**: For one week or two, write down how you spend every hour of your day. This activity will help you understand where your time is going, allowing you to identify areas for improvement. It also helps in pinpointing time-wasting activities and distractions.\n\n3. **Make a To-Do List**: Write down everything that needs to be done. Prioritize tasks based on their urgency and importance using the Eisenhower Matrix:\n   - Urgent & Important (Do First)\n   - Not Urgent but Important (Schedule)\n   - Urgent but Not Important (Delegate)\n   - Not Urgent & Not Important (Eliminate)\n\n4. **Use a Calendar or Planner**: Plan out your day, week, and month using a physical calendar or planner. This visual tool helps in scheduling tasks and appointments more effectively.\n\n5. **Learn to Say No**: Be mindful of commitments that can drain your time without contributing to your goals. Saying "no" politely but firmly protects your schedule from non-essential activities.\n\n6. **Avoid Multitasking**: While it might seem efficient, multitasking often leads to divided attention and decreased productivity. Focus on one task at a time to ensure you\'re giving your best effort.\n\n7. **Take Breaks**: Regular breaks help in maintaining energy levels and preventing burnout. Use the Pomodoro Technique: Work for 25 minutes, then take a 5-minute break before returning to work.\n\n8. **Review and Adjust**: Periodically review how well you\'re managing your time. Identify areas that need improvement and adjust your strategies accordingly.\n\n9. **Use Technology Wisely**: Utilize tools like calendars, reminders, and apps designed for productivity and organization. However, be aware of potential distractions these tools can cause if not used wisely.\n\n10. **Practice Mindfulness and Self-Compassion**: Cultivate a mindset that allows you to adapt to changing situations and forgive yourself when mistakes occur. This approach helps in maintaining a positive relationship with time management.\n\nImplementing these strategies requires patience, self-reflection, and practice. Remember, improving time management is a journey rather than a destination, and it\'s essential to be flexible and adjust your methods as needed.', 'surrogate_response': 'Navigating workplace politics requires diplomacy, tact, and communication skills.', 'similarity_score': 0.10206865070873752}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Extract data from results
queries = [entry['query'] for entry in results]
similarity_scores = [entry['similarity_score'] for entry in results]

# Calculate the total average similarity score
average_similarity_score = np.mean(similarity_scores)

# Plot similarity scores
plt.figure(figsize=(10, 5))
plt.barh(queries, similarity_scores, color='skyblue')
plt.xlabel('Similarity Score')
plt.title('Similarity Scores of Original vs Surrogate Responses')
plt.tight_layout()

# Display the total combined average similarity score as text on the plot
plt.figtext(0.5, -0.05, f"Total Average Similarity Score: {average_similarity_score:.2f}", 
            ha='center', fontsize=12, color='darkblue')

plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.boxplot(data=similarity_scores, color='lightgreen')
plt.title('Distribution of Similarity Scores')
plt.ylabel('Similarity Score')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.scatter(range(len(queries)), similarity_scores, c=similarity_scores, cmap='viridis', s=100)
plt.colorbar(label='Similarity Score')
plt.xticks(range(len(queries)), queries, rotation=90)
plt.ylabel('Similarity Score')
plt.title('Scatter Plot of Similarity Scores for Original vs Surrogate Responses')
plt.tight_layout()
plt.show()

# %%
import seaborn as sns
import numpy as np

# Create a 2D array where each score is in its own row
score_matrix = np.array(similarity_scores).reshape(-1, 1)

plt.figure(figsize=(6, len(queries) / 2))
sns.heatmap(score_matrix, annot=True, cmap='coolwarm', yticklabels=queries, cbar_kws={'label': 'Similarity Score'})
plt.title('Heatmap of Similarity Scores')
plt.xlabel('Similarity')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(queries, similarity_scores, marker='o', linestyle='-', color='teal')
plt.xticks(rotation=90)
plt.ylabel('Similarity Score')
plt.title('Trend of Similarity Scores Across Queries')
plt.tight_layout()
plt.show()
